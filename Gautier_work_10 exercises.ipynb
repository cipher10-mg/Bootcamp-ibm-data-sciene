# %% [markdown]
# exercise1
# # Data science tools and ecosystem

# %% [markdown]
# Exercise 2
#
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Exercise 9
#
# **Objectives**: some of the key takeaways from the course:
# - libraries used by data scentist
# - Create table
# - A few arithmetic expression in python.

# %% [markdown]
# Exercise 3
#
# Some of the popular language that data sceince use are:
# 1. Python
# 2. SQL
# 3. R
# 4. JavaScript
# 5. Scala
# 6. Excel

# %% [markdown]
# Exercise 4
#
# Some of the commonly libraries used by data scientist is:
# - Pandas
# - Metaplolib
# - Numpy
# - Seabirn
# - Scikit-learn
# - pysprk

# %% [markdown]
# Exercise 5
#
# | Data Science tools |
# |--------|
# | Python |
# | R |
# | SQL |
# | Jupyter Notebook |
# | Vs cose |
# | Anaconda |
# | metaplotlib |
# | seaborn |
# | PowerBi |
# | Tableau |

# %% [markdown]
# Exercise 6
#
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# Exercise 7
# This a simple example of arithmetic expression tp multiply 
(3*4) + 5
# Out:
# 17

# %%
# Exercise 8
# This will convert 200 minutes to hours by diving by 60
minutes = 200
minutes / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# Exercise 10
#
# ## Author
# ADOULE Gautier
